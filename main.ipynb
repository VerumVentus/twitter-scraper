# %%
# Run the pip install command below if you don't already have the library
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git

# Run the below command if you don't already have Pandas
# !pip install pandas

# Imports
import snscrape.modules.twitter as sntwitter
import pandas as pd
from datetime import datetime

# %%
# Setting variables to be used below
maxTweets = 500

# Creating list to append tweet data to
tweets_list2 = []
category='REDT'
group='00'
collector='John Wick'
topic='Redtagging of rallyists'
keywords='rally ng rally since:2016-01-01 until:2023-03-17'

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keywords).get_items()):
    # print(tweet, tweet.user.displayname, tweet.user.rawDescription, tweet.user.created, tweet.user.followersCount, tweet.user.friendsCount, tweet.user.location, tweet.viewCount, tweet.user.favouritesCount, tweet.quoteCount)
    if i>maxTweets:
        break
    now = datetime.now()
    tweets_list2.append([now, tweet, group, collector, category, topic, keywords, f"@{tweet.user.username}", tweet.user.displayname, tweet.user.rawDescription, tweet.user.verified, tweet.user.created, tweet.user.friendsCount, tweet.user.followersCount, tweet.user.location, tweet.rawContent, '', 'text', tweet.date, '', '', tweet.user.favouritesCount, tweet.replyCount, tweet.retweetCount, tweet.quoteCount, tweet.viewCount])
    # tweets_list2.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username, tweet])

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=["Timestamp", "Tweet URL", "Group", "Collector", "Category", "Topic", "Keywords", "Account handle", "Account name", "Account bio", "Account type", "Joined", "Following", "Followers", "Location", "Tweet", "Tweet Translated", "Tweet Type", "Date posted", "Screenshot", "Content type", "Likes", "Replies", "Retweets", "Quote Tweets", "Views"])


# Display first 5 entries from dataframe
tweets_df2.head()
# Out:
#                    Timestamp  \
# 0 2023-03-18 01:40:55.290379
# 1 2023-03-18 01:40:55.290379
# 2 2023-03-18 01:40:55.290379
# 3 2023-03-18 01:40:55.290379
# 4 2023-03-18 01:40:55.290379
#
#                                            Tweet URL Group  Collector  \
# 0  https://twitter.com/danybeom/status/1636485194...    00  John Wick
# 1  https://twitter.com/NationalDailyNG/status/163...    00  John Wick
# 2  https://twitter.com/JohnAndrewMer10/status/163...    00  John Wick
# 3  https://twitter.com/mstraveler/status/16364212...    00  John Wick
# 4  https://twitter.com/NgCrawler/status/163640826...    00  John Wick
#
#   Category                    Topic  \
# 0     REDT  Redtagging of rallyists
# 1     REDT  Redtagging of rallyists
# 2     REDT  Redtagging of rallyists
# 3     REDT  Redtagging of rallyists
# 4     REDT  Redtagging of rallyists
#
#                                            Keywords    Account handle  \
# 0  rally ng rally since:2016-01-01 until:2023-03-17         @danybeom
# 1  rally ng rally since:2016-01-01 until:2023-03-17  @NationalDailyNG
# 2  rally ng rally since:2016-01-01 until:2023-03-17  @JohnAndrewMer10
# 3  rally ng rally since:2016-01-01 until:2023-03-17       @mstraveler
# 4  rally ng rally since:2016-01-01 until:2023-03-17        @NgCrawler
#
#                                  Account name  \
# 0                 💚Ɛցցβҽօʍìҽ 🫶 ɱεɱεʝʝαɳɠҡყµɳ💜
# 1                           National Daily NG
# 2                                     jhnndrw
# 3  mstraveler is Kakampink with Common Sense!
# 4                                  Crawler NG
#
#                                          Account bio  ...  Tweet Translated  \
# 0  ~Living in my EggBeoM Era\n~Waiting for the ne...  ...
# 1  A news organization committed to building a ne...  ...
# 2                                                 🇵🇭  ...
# 3  Educator. Professional Editor. Dreamer. Travel...  ...
# 4       Crawler NG is a Nigerian content aggregator.  ...
#
#   Tweet Type               Date posted  Screenshot Content type  Likes  \
# 0       text 2023-03-16 21:50:49+00:00                           12825
# 1       text 2023-03-16 21:15:49+00:00                            1740
# 2       text 2023-03-16 18:38:15+00:00                             262
# 3       text 2023-03-16 17:36:47+00:00                            9005
# 4       text 2023-03-16 16:45:08+00:00                               0
#
#   Replies Retweets Quote Tweets Views
# 0       1        0            0  13.0
# 1       0        0            0  25.0
# 2       0        0            0   8.0
# 3       0        0            0  19.0
# 4       0        0            0   1.0
#
# [5 rows x 26 columns]

# %%
# Export dataframe into a CSV
tweets_df2.to_csv('text-query-tweets.csv', sep=',', index=False)
